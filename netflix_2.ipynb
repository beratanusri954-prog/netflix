# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("netflix_data_storytelling.csv")
df
# Out:
#     Show_ID                 Title    Type Country  Release_Year   Duration  \
# 0      S001                 Dark    Movie      UK          2018     97 min
# 1      S002  Sacred Games Returns   Movie     USA          2016    107 min
# 2      S003    Extraction Returns  Series   India          2024  3 Seasons
# 3      S004        Kota Factory 3   Movie   India          2020     93 min
# 4      S005      Queen's Gambit 3  Series     USA          2023  1 Seasons
# ..      ...                   ...     ...     ...           ...        ...
# 495    S496        Kota Factory 2   Movie     USA          2022     84 min
# 496    S497   Sacred Games Reborn   Movie   India          2021    146 min
# 497    S498    The Witcher Reborn  Series  France          2021  3 Seasons
# 498    S499          Delhi Crime   Series   India          2022  2 Seasons
# 499    S500         Narcos Reborn   Movie   India          2015    146 min
#
#            Genre  IMDb_Rating  Views_Millions Age_Rating Is_Hit
# ...

# %%
df["Duration_num"] = df["Duration"].str.extract(r'(\\d+)').astype(float)
df["Duration_type"] = df["Duration"].str.contains('Season').map({True:'Season',False:'Minutes'})
df['Is_Hit_Bin']=(df['Is_Hit']=='Yes').astype(int)

# %%
df
# Out:
#     Show_ID                 Title    Type Country  Release_Year   Duration  \
# 0      S001                 Dark    Movie      UK          2018     97 min
# 1      S002  Sacred Games Returns   Movie     USA          2016    107 min
# 2      S003    Extraction Returns  Series   India          2024  3 Seasons
# 3      S004        Kota Factory 3   Movie   India          2020     93 min
# 4      S005      Queen's Gambit 3  Series     USA          2023  1 Seasons
# ..      ...                   ...     ...     ...           ...        ...
# 495    S496        Kota Factory 2   Movie     USA          2022     84 min
# 496    S497   Sacred Games Reborn   Movie   India          2021    146 min
# 497    S498    The Witcher Reborn  Series  France          2021  3 Seasons
# 498    S499          Delhi Crime   Series   India          2022  2 Seasons
# 499    S500         Narcos Reborn   Movie   India          2015    146 min
#
# ...

# %%
#which genre gets the most view
genre_views = df.groupby('Genre')['Views_Millions'].mean()
genre_views
# Out:
# Genre
# Action         97.042169
# Comedy         96.403659
# Documentary    85.384848
# Drama          89.670149
# Romance        95.167857
# Sci-Fi         97.960274
# Thriller       95.234247
# Name: Views_Millions, dtype: float64

# %%
genre_views=df.groupby('Genre')["Views_Millions"].mean().reset_index()
sns.barplot(x='Views_Millions',y='Genre',data=genre_views.sort_values('Views_Millions',ascending=False))
plt.title('Avarage Views by Genre')
plt.xlabel('Average Views Millions')
plt.ylabel('Genre')
plt.show()

# %%
a=2
b=4.25

sum=a+b#2.0+4.25
print(sum)
# Out:
# 6.25

# %%
print(type(sum))
# Out:
# <class 'float'>
